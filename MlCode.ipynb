# %%
import numpy as np 
import cv2 
import os 
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns 

from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D

from keras.layers import Flatten
from keras.layers import Dense, Dropout, BatchNormalization
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical 
from sklearn.metrics import classification_report, confusion_matrix  
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import VGG16 
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.regularizers import l2 
from tensorflow.keras.models import load_model, save_model
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23028\2675665949.py in <module>
#       7
#       8 from sklearn.preprocessing import LabelEncoder
# ----> 9 from keras.models import Sequential
#      10 from keras.layers import Conv2D
#      11 from keras.layers import MaxPooling2D
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\keras\__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\keras\__internal__\__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#       5 from keras.__internal__ import losses
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\keras\__internal__\backend\__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras.src.backend import _initialize_variables as initialize_variables
#       4 from keras.src.backend import track_variable
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\keras\src\__init__.py in <module>
#      19 """
#      20
# ---> 21 from keras.src import applications
#      22 from keras.src import distribute
#      23 from keras.src import models
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\keras\src\applications\__init__.py in <module>
#      16
#      17
# ---> 18 from keras.src.applications.convnext import ConvNeXtBase
#      19 from keras.src.applications.convnext import ConvNeXtLarge
#      20 from keras.src.applications.convnext import ConvNeXtSmall
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\keras\src\applications\convnext.py in <module>
#      24
#      25 import numpy as np
# ---> 26 import tensorflow.compat.v2 as tf
#      27
#      28 from keras.src import backend
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\tensorflow\__init__.py in <module>
#      46 _tf2.enable()
#      47
# ---> 48 from tensorflow._api.v2 import __internal__
#      49 from tensorflow._api.v2 import __operators__
#      50 from tensorflow._api.v2 import audio
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py in <module>
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
# ---> 11 from tensorflow._api.v2.__internal__ import distribute
#      12 from tensorflow._api.v2.__internal__ import eager_context
#      13 from tensorflow._api.v2.__internal__ import feature_column
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\tensorflow\_api\v2\__internal__\distribute\__init__.py in <module>
#       6 import sys as _sys
#       7
# ----> 8 from tensorflow._api.v2.__internal__.distribute import combinations
#       9 from tensorflow._api.v2.__internal__.distribute import interim
#      10 from tensorflow._api.v2.__internal__.distribute import multi_process_runner
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\tensorflow\_api\v2\__internal__\distribute\combinations\__init__.py in <module>
#       6 import sys as _sys
#       7
# ----> 8 from tensorflow.python.distribute.combinations import env # line: 456
#       9 from tensorflow.python.distribute.combinations import generate # line: 365
#      10 from tensorflow.python.distribute.combinations import in_main_process # line: 418
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\distribute\combinations.py in <module>
#      31
#      32 from tensorflow.python.client import session
# ---> 33 from tensorflow.python.distribute import collective_all_reduce_strategy
#      34 from tensorflow.python.distribute import distribute_lib
#      35 from tensorflow.python.distribute import multi_process_runner
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\distribute\collective_all_reduce_strategy.py in <module>
#      23 from tensorflow.core.protobuf import tensorflow_server_pb2
#      24 from tensorflow.python.distribute import collective_util
# ---> 25 from tensorflow.python.distribute import cross_device_ops as cross_device_ops_lib
#      26 from tensorflow.python.distribute import cross_device_utils
#      27 from tensorflow.python.distribute import device_util
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\distribute\cross_device_ops.py in <module>
#      26 from tensorflow.python.client import device_lib
#      27 from tensorflow.python.distribute import collective_util
# ---> 28 from tensorflow.python.distribute import cross_device_utils
#      29 from tensorflow.python.distribute import device_util
#      30 from tensorflow.python.distribute import distribute_utils
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\distribute\cross_device_utils.py in <module>
#      20
#      21 from tensorflow.python.distribute import collective_util
# ---> 22 from tensorflow.python.distribute import values as value_lib
#      23 from tensorflow.python.eager import backprop_util
#      24 from tensorflow.python.eager import context
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\distribute\values.py in <module>
#      21 from tensorflow.core.protobuf import struct_pb2
#      22 from tensorflow.python.distribute import device_util
# ---> 23 from tensorflow.python.distribute import distribute_lib
#      24 from tensorflow.python.distribute import packed_distributed_variable as packed
#      25 from tensorflow.python.distribute import reduce_util
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in <module>
#     204 from tensorflow.python.autograph.core import ag_ctx as autograph_ctx
#     205 from tensorflow.python.autograph.impl import api as autograph
# --> 206 from tensorflow.python.data.ops import dataset_ops
#     207 from tensorflow.python.distribute import collective_util
#     208 from tensorflow.python.distribute import device_util
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in <module>
#      31 from tensorflow.python.data.ops import dataset_autograph
#      32 from tensorflow.python.data.ops import debug_mode
# ---> 33 from tensorflow.python.data.ops import iterator_ops
#      34 from tensorflow.python.data.ops import options as options_lib
#      35 from tensorflow.python.data.ops import structured_function
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py in <module>
#      39 from tensorflow.python.saved_model import nested_structure_coder
#      40 from tensorflow.python.trackable import base as trackable
# ---> 41 from tensorflow.python.training.saver import BaseSaverBuilder
#      42 from tensorflow.python.util import _pywrap_utils
#      43 from tensorflow.python.util import deprecation
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\training\saver.py in <module>
#      48 from tensorflow.python.saved_model.pywrap_saved_model import metrics
#      49 from tensorflow.python.trackable import base as trackable
# ---> 50 from tensorflow.python.training import py_checkpoint_reader
#      51 from tensorflow.python.training import training_util
#      52 from tensorflow.python.training.saving import saveable_object
#
# c:\users\overgame\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py in <module>
#      17 from tensorflow.python.framework import errors_impl
#      18 from tensorflow.python.util import compat
# ---> 19 from tensorflow.python.util._pywrap_checkpoint_reader import CheckpointReader
#      20 from tensorflow.python.util.tf_export import tf_export
#      21
#
# SystemError: initialization of _pywrap_checkpoint_reader raised unreported exception

# %%
images_path = './images2'

# %%
X = [] 
y = [] 
width = [] 
height = []

# %%
for subfolder in os.listdir(images_path):
        subfolder_path = os.path.join(images_path, subfolder)
        if os.path.isdir(subfolder_path):
            for filename in os.listdir(subfolder_path):
                img_path = os.path.join(subfolder_path, filename)
                try:
                    img = cv2.imread(img_path)
                    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                    X.append(img)
                    y.append(subfolder)  
                    width.append(img.shape[1]) 
                    height.append(img.shape[0])   
                except Exception as e:
                    print(f"Error loading image {img_path}: {e}")

# %%
print(f'number of images : {len(y)}')
# Out:
# number of images : 355

# %%
plt.imshow(X[147], cmap='gray') 
plt.title(y[147])
# Out:
# Text(0.5, 1.0, 'MehranGhafoorian')

# %%
pd.DataFrame({'height':height,'width':width}).describe()
# Out:
#            height       width
# count  355.000000  355.000000
# mean   210.822535  210.715493
# std    134.246967  134.145741
# min     36.000000   36.000000
# 25%    107.000000  108.000000
# 50%    186.000000  186.000000
# 75%    268.000000  268.000000
# max    958.000000  958.000000

# %%
for i, image in enumerate(X):
    X[i] = cv2.resize(image, (100, 100)).astype(float) / 255

# %%
plt.imshow(X[180], cmap='gray') 
plt.title(y[180])
# Out:
# Text(0.5, 1.0, 'MohamadEsfehani')

# %%
X = np.array(X)
y = np.array(y)

# %%
name_counts = np.unique(y, return_counts=True) 
name_counts_dict = dict(zip(name_counts[0], name_counts[1]))
names, counts = zip(*name_counts_dict.items()) 

label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(y)
num_classes = len(np.unique(encoded_labels))

# %%
plt.figure(figsize=(28,6))
sns.barplot(x=list(names), y=list(counts))
# Out:
# <AxesSubplot:>

# %%
X_train, X_temp, y_train, y_temp = train_test_split(X, encoded_labels, test_size=0.25, stratify=encoded_labels, random_state=42) 
X_test, X_val, y_test, y_val = train_test_split(X_temp, y_temp, test_size=0.4, stratify=y_temp, random_state=42)

# %%
cnn_model_v1 = Sequential() 
cnn_model_v1.add(Conv2D(128, (3, 3), activation='relu', input_shape=(100, 100, 1))) 
cnn_model_v1.add(MaxPooling2D((2, 2))) 


cnn_model_v1.add(Conv2D(64, (3, 3), activation='relu')) 
cnn_model_v1.add(MaxPooling2D((2, 2)))   


cnn_model_v1.add(Conv2D(32, (3, 3), activation='relu')) 
cnn_model_v1.add(MaxPooling2D((2, 2)))  

cnn_model_v1.add(Flatten()) 
 
cnn_model_v1.add(Dense(256, activation='relu')) 

cnn_model_v1.add(Dense(15, activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\HP\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\HP\anaconda3\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
cnn_model_v1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 128)       1280
#
#  max_pooling2d (MaxPooling2  (None, 49, 49, 128)       0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 64)        73792
#
#  max_pooling2d_1 (MaxPoolin  (None, 23, 23, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 32)        18464
#
#  max_pooling2d_2 (MaxPoolin  (None, 10, 10, 32)        0
#  g2D)
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 256)               819456
#
#  dense_1 (Dense)             (None, 15)                3855
#
# =================================================================
# Total params: 916847 (3.50 MB)
# Trainable params: 916847 (3.50 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cnn_model_v1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\HP\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
info = cnn_model_v1.fit(X_train,y_train,epochs=10, validation_data=(X_val, y_val))
# Out:
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\HP\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\HP\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 9/9 [==============================] - 5s 406ms/step - loss: 2.7144 - accuracy: 0.0977 - val_loss: 2.6985 - val_accuracy: 0.1111
# Epoch 2/10
# 9/9 [==============================] - 3s 360ms/step - loss: 2.7113 - accuracy: 0.1128 - val_loss: 2.6908 - val_accuracy: 0.1111
# Epoch 3/10
# 9/9 [==============================] - 3s 357ms/step - loss: 2.6834 - accuracy: 0.1128 - val_loss: 2.6477 - val_accuracy: 0.1111
# Epoch 4/10
# 9/9 [==============================] - 3s 352ms/step - loss: 2.5920 - accuracy: 0.1579 - val_loss: 2.4832 - val_accuracy: 0.1667
# Epoch 5/10
# 9/9 [==============================] - 3s 347ms/step - loss: 2.2870 - accuracy: 0.2669 - val_loss: 2.3798 - val_accuracy: 0.2778
# Epoch 6/10
# 9/9 [==============================] - 3s 353ms/step - loss: 1.9022 - accuracy: 0.3985 - val_loss: 2.2663 - val_accuracy: 0.1944
# Epoch 7/10
# 9/9 [==============================] - 3s 352ms/step - loss: 1.5210 - accuracy: 0.5038 - val_loss: 2.2855 - val_accuracy: 0.2500
# Epoch 8/10
# 9/9 [==============================] - 3s 349ms/step - loss: 1.2584 - accuracy: 0.5977 - val_loss: 2.3212 - val_accuracy: 0.1944
# Epoch 9/10
# 9/9 [==============================] - 3s 342ms/step - loss: 0.9558 - accuracy: 0.6992 - val_loss: 2.3389 - val_accuracy: 0.2778
# Epoch 10/10
# 9/9 [==============================] - 3s 352ms/step - loss: 0.6644 - accuracy: 0.8008 - val_loss: 2.5817 - val_accuracy: 0.3611

# %%
prob_pred = cnn_model_v1.predict(X_test)
# Out:
# 2/2 [==============================] - 1s 98ms/step

# %%
pred = prob_pred.argmax(axis=1)

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.25      0.29         4
#            1       0.00      0.00      0.00         3
#            2       0.33      0.25      0.29         4
#            3       0.33      0.50      0.40         4
#            4       0.50      0.50      0.50         4
#            5       0.25      0.33      0.29         3
#            6       0.33      0.33      0.33         3
#            7       0.50      0.67      0.57         3
#            8       0.00      0.00      0.00         3
#            9       0.00      0.00      0.00         3
#           10       0.38      0.50      0.43         6
#           11       0.22      0.50      0.31         4
#           12       0.00      0.00      0.00         3
#           13       1.00      0.33      0.50         3
#           14       0.00      0.00      0.00         3
#
#     accuracy                           0.30        53
#    macro avg       0.28      0.28      0.26        53
# weighted avg       0.29      0.30      0.28        53
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plt.plot(info.history['loss'], color='red', label='Train')  
plt.plot(info.history['val_loss'], color='blue', label='Validation') 
plt.title('Loss vs iterarion') 
plt.xlabel('epochs.') 
plt.legend()

# %%
plt.plot(info.history['accuracy'], color='red', label='Train')  
plt.plot(info.history['val_accuracy'], color='blue', label='Validation') 
plt.title('Accuracy vs iterarion') 
plt.xlabel('epochs.') 
plt.legend()

# %%
sns.heatmap(confusion_matrix(y_test, pred), annot=True, cmap="Blues", square=True,
            xticklabels=np.arange(15), yticklabels=np.arange(15), linewidths=0.5, linecolor='black')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
cnn_model_v2 = Sequential() 
cnn_model_v2.add(Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 1))) 
cnn_model_v2.add(MaxPooling2D((2, 2))) 


cnn_model_v2.add(Conv2D(32, (3, 3), activation='relu')) 
cnn_model_v2.add(MaxPooling2D((2, 2)))   

cnn_model_v2.add(Flatten()) 
 
cnn_model_v2.add(Dense(32, activation='relu')) 

cnn_model_v2.add(Dense(15, activation='softmax'))

# %%
cnn_model_v2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 98, 98, 32)        320
#
#  max_pooling2d_3 (MaxPoolin  (None, 49, 49, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 47, 47, 32)        9248
#
#  max_pooling2d_4 (MaxPoolin  (None, 23, 23, 32)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 16928)             0
#
#  dense_2 (Dense)             (None, 32)                541728
#
#  dense_3 (Dense)             (None, 15)                495
#
# =================================================================
# Total params: 551791 (2.10 MB)
# Trainable params: 551791 (2.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cnn_model_v2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
info = cnn_model_v2.fit(X_train,y_train,epochs=10, validation_data=(X_val, y_val))
# Out:
# Epoch 1/10
# 9/9 [==============================] - 4s 181ms/step - loss: 2.7270 - accuracy: 0.1015 - val_loss: 2.6988 - val_accuracy: 0.1111
# Epoch 2/10
# 9/9 [==============================] - 1s 97ms/step - loss: 2.6912 - accuracy: 0.1316 - val_loss: 2.6811 - val_accuracy: 0.1389
# Epoch 3/10
# 9/9 [==============================] - 1s 98ms/step - loss: 2.6523 - accuracy: 0.1241 - val_loss: 2.6382 - val_accuracy: 0.1111
# Epoch 4/10
# 9/9 [==============================] - 1s 95ms/step - loss: 2.5882 - accuracy: 0.1541 - val_loss: 2.5945 - val_accuracy: 0.1111
# Epoch 5/10
# 9/9 [==============================] - 1s 96ms/step - loss: 2.4931 - accuracy: 0.1165 - val_loss: 2.5329 - val_accuracy: 0.0833
# Epoch 6/10
# 9/9 [==============================] - 1s 99ms/step - loss: 2.3592 - accuracy: 0.2068 - val_loss: 2.5077 - val_accuracy: 0.1667
# Epoch 7/10
# 9/9 [==============================] - 1s 94ms/step - loss: 2.2403 - accuracy: 0.2707 - val_loss: 2.4488 - val_accuracy: 0.1944
# Epoch 8/10
# 9/9 [==============================] - 1s 96ms/step - loss: 2.1178 - accuracy: 0.3083 - val_loss: 2.4110 - val_accuracy: 0.2500
# Epoch 9/10
# 9/9 [==============================] - 1s 97ms/step - loss: 1.9735 - accuracy: 0.3797 - val_loss: 2.3849 - val_accuracy: 0.2778
# Epoch 10/10
# 9/9 [==============================] - 1s 97ms/step - loss: 1.9159 - accuracy: 0.3835 - val_loss: 2.5859 - val_accuracy: 0.2222

# %%
prob_pred = cnn_model_v2.predict(X_test)
pred = prob_pred.argmax(axis=1) 
print(classification_report(y_test, pred))
# Out:
# 2/2 [==============================] - 0s 25ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.33      0.33      0.33         3
#            2       0.00      0.00      0.00         4
#            3       0.33      0.25      0.29         4
#            4       0.00      0.00      0.00         4
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         3
#            7       0.40      0.67      0.50         3
#            8       0.00      0.00      0.00         3
#            9       0.00      0.00      0.00         3
#           10       0.15      0.83      0.25         6
#           11       0.29      0.50      0.36         4
#           12       0.00      0.00      0.00         3
#           13       0.00      0.00      0.00         3
#           14       0.00      0.00      0.00         3
#
#     accuracy                           0.21        53
#    macro avg       0.10      0.17      0.12        53
# weighted avg       0.10      0.21      0.12        53
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plt.plot(info.history['loss'], color='red', label='Train')  
plt.plot(info.history['val_loss'], color='blue', label='Validation') 
plt.title('Loss vs iterarion') 
plt.xlabel('epochs.') 
plt.legend()

# %%
plt.plot(info.history['accuracy'], color='red', label='Train')  
plt.plot(info.history['val_accuracy'], color='blue', label='Validation') 
plt.title('Accuracy vs iterarion') 
plt.xlabel('epochs.') 
plt.legend()

# %%
sns.heatmap(confusion_matrix(y_test, pred), annot=True, cmap="Blues", square=True,
            xticklabels=np.arange(15), yticklabels=np.arange(15), linewidths=0.5, linecolor='black')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
cnn_model_v3 = Sequential() 
cnn_model_v3.add(Conv2D(128, (5, 5), activation='relu', input_shape=(100, 100, 1))) 
cnn_model_v3.add(MaxPooling2D((2, 2))) 
cnn_model_v3.add(BatchNormalization())

cnn_model_v3.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.00005))) 
cnn_model_v3.add(MaxPooling2D((2, 2)))   
cnn_model_v3.add(BatchNormalization())


cnn_model_v3.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.00005))) 
cnn_model_v3.add(MaxPooling2D((2, 2)))  
cnn_model_v3.add(BatchNormalization())

cnn_model_v3.add(Flatten()) 
 
cnn_model_v3.add(Dense(256, activation='relu')) 
cnn_model_v3.add(Dropout(0.5))  

cnn_model_v3.add(Dense(15, activation='softmax'))

# %%
cnn_model_v3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 96, 96, 128)       3328
#
#  max_pooling2d_5 (MaxPoolin  (None, 48, 48, 128)       0
#  g2D)
#
#  batch_normalization (Batch  (None, 48, 48, 128)       512
#  Normalization)
#
#  conv2d_6 (Conv2D)           (None, 46, 46, 64)        73792
#
#  max_pooling2d_6 (MaxPoolin  (None, 23, 23, 64)        0
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 23, 23, 64)        256
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 21, 21, 32)        18464
#
#  max_pooling2d_7 (MaxPoolin  (None, 10, 10, 32)        0
#  g2D)
#
#  batch_normalization_2 (Bat  (None, 10, 10, 32)        128
#  chNormalization)
#
#  flatten_2 (Flatten)         (None, 3200)              0
#
#  dense_4 (Dense)             (None, 256)               819456
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_5 (Dense)             (None, 15)                3855
#
# =================================================================
# Total params: 919791 (3.51 MB)
# Trainable params: 919343 (3.51 MB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %%
optimizer = Adam(learning_rate=0.001)    
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
cnn_model_v3.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
info = cnn_model_v3.fit(X_train,y_train,epochs=100, validation_data=(X_val, y_val), verbose=2,
                       callbacks=[reduce_lr])
# Out:
# Epoch 1/100
# 9/9 - 11s - loss: 3.5365 - accuracy: 0.1316 - val_loss: 2.7196 - val_accuracy: 0.0833 - lr: 0.0010 - 11s/epoch - 1s/step
# Epoch 2/100
# 9/9 - 4s - loss: 1.9080 - accuracy: 0.4586 - val_loss: 2.7670 - val_accuracy: 0.0833 - lr: 0.0010 - 4s/epoch - 445ms/step
# Epoch 3/100
# 9/9 - 4s - loss: 1.3972 - accuracy: 0.5714 - val_loss: 2.8249 - val_accuracy: 0.0556 - lr: 0.0010 - 4s/epoch - 449ms/step
# Epoch 4/100
# 9/9 - 4s - loss: 0.8136 - accuracy: 0.7293 - val_loss: 2.8685 - val_accuracy: 0.1111 - lr: 0.0010 - 4s/epoch - 456ms/step
# Epoch 5/100
# 9/9 - 4s - loss: 0.5249 - accuracy: 0.8045 - val_loss: 2.8369 - val_accuracy: 0.1111 - lr: 0.0010 - 4s/epoch - 455ms/step
# Epoch 6/100
# 9/9 - 4s - loss: 0.3326 - accuracy: 0.9211 - val_loss: 2.8697 - val_accuracy: 0.0833 - lr: 0.0010 - 4s/epoch - 448ms/step
# Epoch 7/100
# 9/9 - 4s - loss: 0.2151 - accuracy: 0.9624 - val_loss: 3.0085 - val_accuracy: 0.0833 - lr: 3.1623e-04 - 4s/epoch - 478ms/step
# Epoch 8/100
# 9/9 - 4s - loss: 0.2014 - accuracy: 0.9398 - val_loss: 3.1503 - val_accuracy: 0.0833 - lr: 3.1623e-04 - 4s/epoch - 472ms/step
# Epoch 9/100
# 9/9 - 4s - loss: 0.1542 - accuracy: 0.9624 - val_loss: 3.2507 - val_accuracy: 0.0833 - lr: 3.1623e-04 - 4s/epoch - 461ms/step
# Epoch 10/100
# 9/9 - 4s - loss: 0.1393 - accuracy: 0.9737 - val_loss: 3.3344 - val_accuracy: 0.0833 - lr: 3.1623e-04 - 4s/epoch - 435ms/step
# Epoch 11/100
# 9/9 - 4s - loss: 0.1129 - accuracy: 0.9737 - val_loss: 3.4408 - val_accuracy: 0.0833 - lr: 3.1623e-04 - 4s/epoch - 437ms/step
# Epoch 12/100
# 9/9 - 4s - loss: 0.0834 - accuracy: 0.9887 - val_loss: 3.5353 - val_accuracy: 0.0833 - lr: 1.0000e-04 - 4s/epoch - 433ms/step
# Epoch 13/100
# 9/9 - 4s - loss: 0.0729 - accuracy: 0.9925 - val_loss: 3.6243 - val_accuracy: 0.0833 - lr: 1.0000e-04 - 4s/epoch - 438ms/step
# Epoch 14/100
# 9/9 - 4s - loss: 0.0829 - accuracy: 0.9887 - val_loss: 3.7217 - val_accuracy: 0.0833 - lr: 1.0000e-04 - 4s/epoch - 433ms/step
# Epoch 15/100
# 9/9 - 4s - loss: 0.0619 - accuracy: 0.9962 - val_loss: 3.8089 - val_accuracy: 0.0833 - lr: 1.0000e-04 - 4s/epoch - 437ms/step
# Epoch 16/100
# 9/9 - 4s - loss: 0.0684 - accuracy: 0.9925 - val_loss: 3.8968 - val_accuracy: 0.0833 - lr: 1.0000e-04 - 4s/epoch - 436ms/step
# Epoch 17/100
# 9/9 - 4s - loss: 0.0778 - accuracy: 0.9925 - val_loss: 3.9917 - val_accuracy: 0.0833 - lr: 3.1623e-05 - 4s/epoch - 427ms/step
# Epoch 18/100
# 9/9 - 4s - loss: 0.0748 - accuracy: 0.9850 - val_loss: 4.0751 - val_accuracy: 0.0833 - lr: 3.1623e-05 - 4s/epoch - 432ms/step
# Epoch 19/100
# 9/9 - 4s - loss: 0.0807 - accuracy: 0.9812 - val_loss: 4.1319 - val_accuracy: 0.0833 - lr: 3.1623e-05 - 4s/epoch - 427ms/step
# Epoch 20/100
# 9/9 - 4s - loss: 0.0873 - accuracy: 0.9850 - val_loss: 4.1726 - val_accuracy: 0.0833 - lr: 3.1623e-05 - 4s/epoch - 446ms/step
# Epoch 21/100
# 9/9 - 4s - loss: 0.0824 - accuracy: 0.9887 - val_loss: 4.2043 - val_accuracy: 0.0833 - lr: 3.1623e-05 - 4s/epoch - 438ms/step
# Epoch 22/100
# 9/9 - 4s - loss: 0.0799 - accuracy: 0.9962 - val_loss: 4.2571 - val_accuracy: 0.0833 - lr: 1.0000e-05 - 4s/epoch - 427ms/step
# Epoch 23/100
# 9/9 - 4s - loss: 0.0712 - accuracy: 0.9887 - val_loss: 4.2990 - val_accuracy: 0.0833 - lr: 1.0000e-05 - 4s/epoch - 428ms/step
# Epoch 24/100
# 9/9 - 4s - loss: 0.0577 - accuracy: 0.9925 - val_loss: 4.3308 - val_accuracy: 0.0833 - lr: 1.0000e-05 - 4s/epoch - 439ms/step
# Epoch 25/100
# 9/9 - 4s - loss: 0.0762 - accuracy: 0.9962 - val_loss: 4.3576 - val_accuracy: 0.0833 - lr: 1.0000e-05 - 4s/epoch - 442ms/step
# Epoch 26/100
# 9/9 - 4s - loss: 0.0701 - accuracy: 0.9887 - val_loss: 4.3803 - val_accuracy: 0.0833 - lr: 1.0000e-05 - 4s/epoch - 451ms/step
# Epoch 27/100
# 9/9 - 4s - loss: 0.0747 - accuracy: 0.9925 - val_loss: 4.3965 - val_accuracy: 0.0833 - lr: 3.1623e-06 - 4s/epoch - 425ms/step
# Epoch 28/100
# 9/9 - 4s - loss: 0.0794 - accuracy: 0.9925 - val_loss: 4.4051 - val_accuracy: 0.0833 - lr: 3.1623e-06 - 4s/epoch - 423ms/step
# Epoch 29/100
# 9/9 - 4s - loss: 0.0710 - accuracy: 0.9925 - val_loss: 4.4099 - val_accuracy: 0.0833 - lr: 3.1623e-06 - 4s/epoch - 436ms/step
# Epoch 30/100
# 9/9 - 4s - loss: 0.0698 - accuracy: 0.9962 - val_loss: 4.4090 - val_accuracy: 0.0833 - lr: 3.1623e-06 - 4s/epoch - 426ms/step
# Epoch 31/100
# 9/9 - 4s - loss: 0.0657 - accuracy: 0.9962 - val_loss: 4.3953 - val_accuracy: 0.0833 - lr: 3.1623e-06 - 4s/epoch - 446ms/step
# Epoch 32/100
# 9/9 - 4s - loss: 0.0869 - accuracy: 0.9925 - val_loss: 4.3754 - val_accuracy: 0.0833 - lr: 1.0000e-06 - 4s/epoch - 437ms/step
# Epoch 33/100
# 9/9 - 4s - loss: 0.0718 - accuracy: 0.9925 - val_loss: 4.3544 - val_accuracy: 0.0833 - lr: 1.0000e-06 - 4s/epoch - 466ms/step
# Epoch 34/100
# 9/9 - 4s - loss: 0.0711 - accuracy: 0.9925 - val_loss: 4.3240 - val_accuracy: 0.0833 - lr: 1.0000e-06 - 4s/epoch - 424ms/step
# Epoch 35/100
# 9/9 - 4s - loss: 0.0722 - accuracy: 0.9887 - val_loss: 4.2871 - val_accuracy: 0.0833 - lr: 1.0000e-06 - 4s/epoch - 412ms/step
# Epoch 36/100
# 9/9 - 4s - loss: 0.0561 - accuracy: 0.9925 - val_loss: 4.2415 - val_accuracy: 0.0833 - lr: 1.0000e-06 - 4s/epoch - 468ms/step
# Epoch 37/100
# 9/9 - 4s - loss: 0.0795 - accuracy: 0.9887 - val_loss: 4.1853 - val_accuracy: 0.0833 - lr: 3.1623e-07 - 4s/epoch - 396ms/step
# Epoch 38/100
# 9/9 - 4s - loss: 0.0659 - accuracy: 0.9962 - val_loss: 4.1244 - val_accuracy: 0.0833 - lr: 3.1623e-07 - 4s/epoch - 398ms/step
# Epoch 39/100
# 9/9 - 3s - loss: 0.0862 - accuracy: 0.9737 - val_loss: 4.0592 - val_accuracy: 0.1111 - lr: 3.1623e-07 - 3s/epoch - 388ms/step
# Epoch 40/100
# 9/9 - 4s - loss: 0.0813 - accuracy: 0.9850 - val_loss: 3.9871 - val_accuracy: 0.1111 - lr: 3.1623e-07 - 4s/epoch - 398ms/step
# Epoch 41/100
# 9/9 - 3s - loss: 0.0822 - accuracy: 0.9887 - val_loss: 3.9134 - val_accuracy: 0.1111 - lr: 3.1623e-07 - 3s/epoch - 360ms/step
# Epoch 42/100
# 9/9 - 3s - loss: 0.0640 - accuracy: 1.0000 - val_loss: 3.8370 - val_accuracy: 0.1389 - lr: 1.0000e-07 - 3s/epoch - 347ms/step
# Epoch 43/100
# 9/9 - 3s - loss: 0.0696 - accuracy: 0.9887 - val_loss: 3.7605 - val_accuracy: 0.1667 - lr: 1.0000e-07 - 3s/epoch - 334ms/step
# Epoch 44/100
# 9/9 - 3s - loss: 0.0647 - accuracy: 0.9962 - val_loss: 3.6815 - val_accuracy: 0.1667 - lr: 1.0000e-07 - 3s/epoch - 360ms/step
# Epoch 45/100
# 9/9 - 3s - loss: 0.0582 - accuracy: 0.9925 - val_loss: 3.6015 - val_accuracy: 0.1667 - lr: 1.0000e-07 - 3s/epoch - 351ms/step
# Epoch 46/100
# 9/9 - 3s - loss: 0.0838 - accuracy: 0.9812 - val_loss: 3.5183 - val_accuracy: 0.1667 - lr: 1.0000e-07 - 3s/epoch - 344ms/step
# Epoch 47/100
# 9/9 - 3s - loss: 0.0593 - accuracy: 0.9962 - val_loss: 3.4304 - val_accuracy: 0.1667 - lr: 3.1623e-08 - 3s/epoch - 339ms/step
# Epoch 48/100
# 9/9 - 3s - loss: 0.0714 - accuracy: 0.9962 - val_loss: 3.3425 - val_accuracy: 0.1667 - lr: 3.1623e-08 - 3s/epoch - 345ms/step
# Epoch 49/100
# 9/9 - 3s - loss: 0.0633 - accuracy: 0.9925 - val_loss: 3.2515 - val_accuracy: 0.1667 - lr: 3.1623e-08 - 3s/epoch - 359ms/step
# Epoch 50/100
# 9/9 - 3s - loss: 0.0533 - accuracy: 0.9962 - val_loss: 3.1618 - val_accuracy: 0.2222 - lr: 3.1623e-08 - 3s/epoch - 340ms/step
# Epoch 51/100
# 9/9 - 3s - loss: 0.0857 - accuracy: 0.9850 - val_loss: 3.0759 - val_accuracy: 0.2222 - lr: 3.1623e-08 - 3s/epoch - 330ms/step
# Epoch 52/100
# 9/9 - 3s - loss: 0.0632 - accuracy: 0.9925 - val_loss: 2.9898 - val_accuracy: 0.2222 - lr: 1.0000e-08 - 3s/epoch - 353ms/step
# Epoch 53/100
# 9/9 - 3s - loss: 0.0595 - accuracy: 1.0000 - val_loss: 2.9073 - val_accuracy: 0.2222 - lr: 1.0000e-08 - 3s/epoch - 360ms/step
# Epoch 54/100
# 9/9 - 3s - loss: 0.0678 - accuracy: 0.9850 - val_loss: 2.8225 - val_accuracy: 0.2222 - lr: 1.0000e-08 - 3s/epoch - 351ms/step
# Epoch 55/100
# 9/9 - 3s - loss: 0.0704 - accuracy: 0.9925 - val_loss: 2.7433 - val_accuracy: 0.2222 - lr: 1.0000e-08 - 3s/epoch - 349ms/step
# Epoch 56/100
# 9/9 - 3s - loss: 0.0882 - accuracy: 0.9774 - val_loss: 2.6664 - val_accuracy: 0.2222 - lr: 1.0000e-08 - 3s/epoch - 372ms/step
# Epoch 57/100
# 9/9 - 3s - loss: 0.0579 - accuracy: 1.0000 - val_loss: 2.5905 - val_accuracy: 0.2222 - lr: 1.0000e-08 - 3s/epoch - 366ms/step
# Epoch 58/100
# 9/9 - 4s - loss: 0.0648 - accuracy: 0.9887 - val_loss: 2.5138 - val_accuracy: 0.2222 - lr: 1.0000e-08 - 4s/epoch - 389ms/step
# Epoch 59/100
# 9/9 - 4s - loss: 0.0842 - accuracy: 0.9774 - val_loss: 2.4389 - val_accuracy: 0.2222 - lr: 1.0000e-08 - 4s/epoch - 447ms/step
# Epoch 60/100
# 9/9 - 4s - loss: 0.0700 - accuracy: 0.9925 - val_loss: 2.3679 - val_accuracy: 0.2222 - lr: 1.0000e-08 - 4s/epoch - 412ms/step
# Epoch 61/100
# 9/9 - 3s - loss: 0.0836 - accuracy: 0.9962 - val_loss: 2.2986 - val_accuracy: 0.2778 - lr: 1.0000e-08 - 3s/epoch - 379ms/step
# Epoch 62/100
# 9/9 - 4s - loss: 0.0712 - accuracy: 0.9887 - val_loss: 2.2395 - val_accuracy: 0.3056 - lr: 1.0000e-08 - 4s/epoch - 474ms/step
# Epoch 63/100
# 9/9 - 3s - loss: 0.0612 - accuracy: 1.0000 - val_loss: 2.1854 - val_accuracy: 0.3611 - lr: 1.0000e-08 - 3s/epoch - 385ms/step
# Epoch 64/100
# 9/9 - 3s - loss: 0.0708 - accuracy: 0.9925 - val_loss: 2.1315 - val_accuracy: 0.3333 - lr: 1.0000e-08 - 3s/epoch - 368ms/step
# Epoch 65/100
# 9/9 - 4s - loss: 0.0586 - accuracy: 0.9925 - val_loss: 2.0831 - val_accuracy: 0.3611 - lr: 1.0000e-08 - 4s/epoch - 423ms/step
# Epoch 66/100
# 9/9 - 3s - loss: 0.0760 - accuracy: 0.9887 - val_loss: 2.0388 - val_accuracy: 0.3611 - lr: 1.0000e-08 - 3s/epoch - 382ms/step
# Epoch 67/100
# 9/9 - 3s - loss: 0.0715 - accuracy: 0.9925 - val_loss: 1.9978 - val_accuracy: 0.3611 - lr: 1.0000e-08 - 3s/epoch - 383ms/step
# Epoch 68/100
# 9/9 - 4s - loss: 0.0636 - accuracy: 0.9887 - val_loss: 1.9620 - val_accuracy: 0.3611 - lr: 1.0000e-08 - 4s/epoch - 455ms/step
# Epoch 69/100
# 9/9 - 3s - loss: 0.0765 - accuracy: 0.9812 - val_loss: 1.9301 - val_accuracy: 0.4167 - lr: 1.0000e-08 - 3s/epoch - 377ms/step
# Epoch 70/100
# 9/9 - 4s - loss: 0.0723 - accuracy: 0.9925 - val_loss: 1.9077 - val_accuracy: 0.4167 - lr: 1.0000e-08 - 4s/epoch - 401ms/step
# Epoch 71/100
# 9/9 - 4s - loss: 0.0619 - accuracy: 0.9887 - val_loss: 1.8865 - val_accuracy: 0.4444 - lr: 1.0000e-08 - 4s/epoch - 444ms/step
# Epoch 72/100
# 9/9 - 3s - loss: 0.0756 - accuracy: 0.9925 - val_loss: 1.8700 - val_accuracy: 0.4722 - lr: 1.0000e-08 - 3s/epoch - 380ms/step
# Epoch 73/100
# 9/9 - 4s - loss: 0.0611 - accuracy: 0.9887 - val_loss: 1.8577 - val_accuracy: 0.4722 - lr: 1.0000e-08 - 4s/epoch - 418ms/step
# Epoch 74/100
# 9/9 - 4s - loss: 0.0553 - accuracy: 1.0000 - val_loss: 1.8505 - val_accuracy: 0.4722 - lr: 1.0000e-08 - 4s/epoch - 418ms/step
# Epoch 75/100
# 9/9 - 4s - loss: 0.0796 - accuracy: 0.9850 - val_loss: 1.8472 - val_accuracy: 0.4722 - lr: 1.0000e-08 - 4s/epoch - 395ms/step
# Epoch 76/100
# 9/9 - 4s - loss: 0.0580 - accuracy: 0.9887 - val_loss: 1.8465 - val_accuracy: 0.4444 - lr: 1.0000e-08 - 4s/epoch - 425ms/step
# Epoch 77/100
# 9/9 - 5s - loss: 0.0518 - accuracy: 1.0000 - val_loss: 1.8475 - val_accuracy: 0.4444 - lr: 1.0000e-08 - 5s/epoch - 518ms/step
# Epoch 78/100
# 9/9 - 5s - loss: 0.0609 - accuracy: 0.9925 - val_loss: 1.8489 - val_accuracy: 0.4722 - lr: 1.0000e-08 - 5s/epoch - 516ms/step
# Epoch 79/100
# 9/9 - 4s - loss: 0.0777 - accuracy: 0.9850 - val_loss: 1.8509 - val_accuracy: 0.4722 - lr: 1.0000e-08 - 4s/epoch - 436ms/step
# Epoch 80/100
# 9/9 - 4s - loss: 0.0915 - accuracy: 0.9850 - val_loss: 1.8562 - val_accuracy: 0.4722 - lr: 1.0000e-08 - 4s/epoch - 425ms/step
# Epoch 81/100
# 9/9 - 4s - loss: 0.0933 - accuracy: 0.9887 - val_loss: 1.8628 - val_accuracy: 0.4722 - lr: 1.0000e-08 - 4s/epoch - 495ms/step
# Epoch 82/100
# 9/9 - 4s - loss: 0.0660 - accuracy: 0.9925 - val_loss: 1.8692 - val_accuracy: 0.4722 - lr: 3.1623e-09 - 4s/epoch - 474ms/step
# Epoch 83/100
# 9/9 - 4s - loss: 0.0610 - accuracy: 0.9925 - val_loss: 1.8756 - val_accuracy: 0.4722 - lr: 3.1623e-09 - 4s/epoch - 482ms/step
# Epoch 84/100
# 9/9 - 4s - loss: 0.0725 - accuracy: 0.9887 - val_loss: 1.8819 - val_accuracy: 0.5000 - lr: 3.1623e-09 - 4s/epoch - 410ms/step
# Epoch 85/100
# 9/9 - 4s - loss: 0.0658 - accuracy: 0.9925 - val_loss: 1.8876 - val_accuracy: 0.4722 - lr: 3.1623e-09 - 4s/epoch - 415ms/step
# Epoch 86/100
# 9/9 - 4s - loss: 0.0669 - accuracy: 0.9925 - val_loss: 1.8943 - val_accuracy: 0.4722 - lr: 3.1623e-09 - 4s/epoch - 411ms/step
# Epoch 87/100
# 9/9 - 4s - loss: 0.0773 - accuracy: 0.9887 - val_loss: 1.9007 - val_accuracy: 0.4722 - lr: 1.0000e-09 - 4s/epoch - 415ms/step
# Epoch 88/100
# 9/9 - 3s - loss: 0.0750 - accuracy: 0.9850 - val_loss: 1.9059 - val_accuracy: 0.4722 - lr: 1.0000e-09 - 3s/epoch - 385ms/step
# Epoch 89/100
# 9/9 - 3s - loss: 0.0844 - accuracy: 0.9887 - val_loss: 1.9106 - val_accuracy: 0.4722 - lr: 1.0000e-09 - 3s/epoch - 372ms/step
# Epoch 90/100
# 9/9 - 4s - loss: 0.0641 - accuracy: 0.9962 - val_loss: 1.9166 - val_accuracy: 0.4722 - lr: 1.0000e-09 - 4s/epoch - 391ms/step
# Epoch 91/100
# 9/9 - 4s - loss: 0.0885 - accuracy: 0.9774 - val_loss: 1.9219 - val_accuracy: 0.4722 - lr: 1.0000e-09 - 4s/epoch - 405ms/step
# Epoch 92/100
# 9/9 - 4s - loss: 0.0721 - accuracy: 0.9850 - val_loss: 1.9272 - val_accuracy: 0.5000 - lr: 3.1623e-10 - 4s/epoch - 394ms/step
# Epoch 93/100
# 9/9 - 4s - loss: 0.0706 - accuracy: 0.9887 - val_loss: 1.9322 - val_accuracy: 0.5000 - lr: 3.1623e-10 - 4s/epoch - 395ms/step
# Epoch 94/100
# 9/9 - 4s - loss: 0.0797 - accuracy: 0.9887 - val_loss: 1.9372 - val_accuracy: 0.5278 - lr: 3.1623e-10 - 4s/epoch - 444ms/step
# Epoch 95/100
# 9/9 - 4s - loss: 0.0694 - accuracy: 0.9925 - val_loss: 1.9424 - val_accuracy: 0.5556 - lr: 3.1623e-10 - 4s/epoch - 405ms/step
# Epoch 96/100
# 9/9 - 3s - loss: 0.0734 - accuracy: 0.9812 - val_loss: 1.9475 - val_accuracy: 0.5278 - lr: 3.1623e-10 - 3s/epoch - 366ms/step
# Epoch 97/100
# 9/9 - 3s - loss: 0.0632 - accuracy: 0.9925 - val_loss: 1.9522 - val_accuracy: 0.5278 - lr: 1.0000e-10 - 3s/epoch - 376ms/step
# Epoch 98/100
# 9/9 - 3s - loss: 0.0847 - accuracy: 0.9887 - val_loss: 1.9569 - val_accuracy: 0.5278 - lr: 1.0000e-10 - 3s/epoch - 366ms/step
# Epoch 99/100
# 9/9 - 4s - loss: 0.0791 - accuracy: 0.9925 - val_loss: 1.9605 - val_accuracy: 0.5278 - lr: 1.0000e-10 - 4s/epoch - 438ms/step
# Epoch 100/100
# 9/9 - 4s - loss: 0.0770 - accuracy: 0.9812 - val_loss: 1.9638 - val_accuracy: 0.5278 - lr: 1.0000e-10 - 4s/epoch - 435ms/step

# %%
prob_pred = cnn_model_v3.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 83ms/step

# %%
pred = prob_pred.argmax(axis=1)

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.25      0.33      0.29         3
#            2       0.33      0.50      0.40         4
#            3       0.60      0.75      0.67         4
#            4       0.50      0.25      0.33         4
#            5       0.67      0.67      0.67         3
#            6       0.50      0.33      0.40         3
#            7       0.50      1.00      0.67         3
#            8       0.40      0.67      0.50         3
#            9       0.00      0.00      0.00         3
#           10       0.57      0.67      0.62         6
#           11       0.50      0.50      0.50         4
#           12       0.00      0.00      0.00         3
#           13       1.00      0.33      0.50         3
#           14       0.00      0.00      0.00         3
#
#     accuracy                           0.42        53
#    macro avg       0.39      0.40      0.37        53
# weighted avg       0.40      0.42      0.38        53
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plt.plot(info.history['loss'], color='red', label='Train')  
plt.plot(info.history['val_loss'], color='blue', label='Validation') 
plt.title('Loss vs iterarion') 
plt.xlabel('epochs.') 
plt.legend()

# %%
plt.plot(info.history['accuracy'], color='red', label='Train')  
plt.plot(info.history['val_accuracy'], color='blue', label='Validation') 
plt.title('Accuracy vs iterarion') 
plt.xlabel('epochs.') 
plt.legend()

# %%
sns.heatmap(confusion_matrix(y_test, pred), annot=True, cmap="Blues", square=True,
            xticklabels=np.arange(15), yticklabels=np.arange(15), linewidths=0.5, linecolor='black')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
augmenter = ImageDataGenerator(
    rotation_range=30,  
    horizontal_flip=True,
    vertical_flip=True, 
    shear_range=0.2, 
    zoom_range=0.2
   ) 

augmenter = ImageDataGenerator(
    rotation_range=30,  
    horizontal_flip=True,
    vertical_flip=True, 
    shear_range=0.2, 
    zoom_range=0.2
   )

# %%
X = X.reshape(X.shape[0], 100, 100, 1)
X_augmented = []
y_augmented = []

for i in range(X.shape[0]):
    original_image = X[i]
    original_label = encoded_labels[i]

    original_image = original_image.reshape(1, 100, 100, 1)
    augmented_images = []

    for _ in range(2):  
        augmented_image = next(augmenter.flow(original_image, batch_size=1))[0]
        augmented_images.append(augmented_image)

    X_augmented.extend([original_image[0]] + augmented_images)
    y_augmented.extend([original_label] * 3)

# %%
X_augmented = np.array(X_augmented) 
y_augmented = np.array(y_augmented)

# %%
plt.imshow(X_augmented[421], cmap='gray') 
label_encoder.inverse_transform([y_augmented[421]])
# Out:
# array(['MehranGhafoorian'], dtype='<U18')

# %%
X_train_augmented, X_temp, y_train_augmented, y_temp = train_test_split(X_augmented, y_augmented, test_size=0.25, stratify=y_augmented, random_state=42)
X_test_augmented, X_val_augmented, y_test_augmented, y_val_augmented = train_test_split(X_temp, y_temp, test_size=0.4, stratify=y_temp, random_state=42)

# %%
cnn_model_v4 = Sequential() 
cnn_model_v4.add(Conv2D(128, (5, 5), activation='relu', input_shape=(100, 100, 1))) 
cnn_model_v4.add(MaxPooling2D((2, 2))) 
cnn_model_v4.add(BatchNormalization())

cnn_model_v4.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(0.00005))) 
cnn_model_v4.add(MaxPooling2D((2, 2)))   
cnn_model_v4.add(BatchNormalization())


cnn_model_v4.add(Conv2D(32, (3, 3), activation='relu', kernel_regularizer=l2(0.00005))) 
cnn_model_v4.add(MaxPooling2D((2, 2)))  
cnn_model_v4.add(BatchNormalization())

cnn_model_v4.add(Flatten()) 
 
cnn_model_v4.add(Dense(64, activation='relu')) 
cnn_model_v4.add(Dropout(0.5))  

cnn_model_v4.add(Dense(15, activation='softmax'))

# %%
optimizer = Adam(learning_rate=0.001)    
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
cnn_model_v4.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
info = cnn_model_v4.fit(X_augmented,y_augmented,epochs=20, validation_data=(X_val_augmented, y_val_augmented), verbose=2,
                       callbacks=[reduce_lr])
# Out:
# Epoch 1/20
# 34/34 - 16s - loss: 3.1175 - accuracy: 0.1277 - val_loss: 2.7303 - val_accuracy: 0.0841 - lr: 0.0010 - 16s/epoch - 485ms/step
# Epoch 2/20
# 34/34 - 14s - loss: 2.4429 - accuracy: 0.2244 - val_loss: 2.9822 - val_accuracy: 0.0654 - lr: 0.0010 - 14s/epoch - 412ms/step
# Epoch 3/20
# 34/34 - 13s - loss: 2.1068 - accuracy: 0.3174 - val_loss: 2.8748 - val_accuracy: 0.1121 - lr: 0.0010 - 13s/epoch - 396ms/step
# Epoch 4/20
# 34/34 - 14s - loss: 1.8035 - accuracy: 0.4216 - val_loss: 3.7431 - val_accuracy: 0.0654 - lr: 0.0010 - 14s/epoch - 399ms/step
# Epoch 5/20
# 34/34 - 15s - loss: 1.5322 - accuracy: 0.4854 - val_loss: 3.5897 - val_accuracy: 0.0561 - lr: 0.0010 - 15s/epoch - 429ms/step
# Epoch 6/20
# 34/34 - 14s - loss: 1.4692 - accuracy: 0.5033 - val_loss: 3.9080 - val_accuracy: 0.0654 - lr: 0.0010 - 14s/epoch - 404ms/step
# Epoch 7/20
# 34/34 - 13s - loss: 1.1696 - accuracy: 0.6085 - val_loss: 3.3768 - val_accuracy: 0.0748 - lr: 3.1623e-04 - 13s/epoch - 385ms/step
# Epoch 8/20
# 34/34 - 14s - loss: 1.0262 - accuracy: 0.6638 - val_loss: 3.8801 - val_accuracy: 0.0561 - lr: 3.1623e-04 - 14s/epoch - 405ms/step
# Epoch 9/20
# 34/34 - 14s - loss: 0.9845 - accuracy: 0.6695 - val_loss: 3.7160 - val_accuracy: 0.0748 - lr: 3.1623e-04 - 14s/epoch - 422ms/step
# Epoch 10/20
# 34/34 - 13s - loss: 0.8451 - accuracy: 0.7211 - val_loss: 3.4092 - val_accuracy: 0.0748 - lr: 3.1623e-04 - 13s/epoch - 370ms/step
# Epoch 11/20
# 34/34 - 12s - loss: 0.8741 - accuracy: 0.7099 - val_loss: 3.0938 - val_accuracy: 0.1215 - lr: 3.1623e-04 - 12s/epoch - 364ms/step
# Epoch 12/20
# 34/34 - 13s - loss: 0.7806 - accuracy: 0.7493 - val_loss: 2.6292 - val_accuracy: 0.2056 - lr: 1.0000e-04 - 13s/epoch - 385ms/step
# Epoch 13/20
# 34/34 - 13s - loss: 0.7805 - accuracy: 0.7371 - val_loss: 2.3392 - val_accuracy: 0.2336 - lr: 1.0000e-04 - 13s/epoch - 395ms/step
# Epoch 14/20
# 34/34 - 14s - loss: 0.7239 - accuracy: 0.7671 - val_loss: 1.8915 - val_accuracy: 0.3738 - lr: 1.0000e-04 - 14s/epoch - 406ms/step
# Epoch 15/20
# 34/34 - 14s - loss: 0.7462 - accuracy: 0.7643 - val_loss: 1.5106 - val_accuracy: 0.4953 - lr: 1.0000e-04 - 14s/epoch - 426ms/step
# Epoch 16/20
# 34/34 - 13s - loss: 0.7149 - accuracy: 0.7869 - val_loss: 1.1434 - val_accuracy: 0.6729 - lr: 1.0000e-04 - 13s/epoch - 396ms/step
# Epoch 17/20
# 34/34 - 13s - loss: 0.7144 - accuracy: 0.7728 - val_loss: 0.9010 - val_accuracy: 0.7196 - lr: 1.0000e-04 - 13s/epoch - 382ms/step
# Epoch 18/20
# 34/34 - 13s - loss: 0.6617 - accuracy: 0.7972 - val_loss: 0.6750 - val_accuracy: 0.8692 - lr: 1.0000e-04 - 13s/epoch - 383ms/step
# Epoch 19/20
# 34/34 - 14s - loss: 0.6363 - accuracy: 0.7897 - val_loss: 0.5394 - val_accuracy: 0.8972 - lr: 1.0000e-04 - 14s/epoch - 404ms/step
# Epoch 20/20
# 34/34 - 13s - loss: 0.6108 - accuracy: 0.8009 - val_loss: 0.4259 - val_accuracy: 0.9439 - lr: 1.0000e-04 - 13s/epoch - 381ms/step

# %%
prob_pred = cnn_model_v4.predict(X_test_augmented)
# Out:
# 5/5 [==============================] - 1s 109ms/step

# %%
pred = prob_pred.argmax(axis=1)

# %%
print(classification_report(y_test_augmented, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        11
#            1       1.00      1.00      1.00        10
#            2       0.73      1.00      0.85        11
#            3       1.00      1.00      1.00        11
#            4       1.00      1.00      1.00        10
#            5       1.00      0.89      0.94         9
#            6       1.00      1.00      1.00        10
#            7       1.00      1.00      1.00        11
#            8       1.00      0.89      0.94         9
#            9       0.89      0.89      0.89         9
#           10       1.00      1.00      1.00        18
#           11       1.00      0.91      0.95        11
#           12       0.90      1.00      0.95         9
#           13       1.00      0.90      0.95        10
#           14       0.89      0.73      0.80        11
#
#     accuracy                           0.95       160
#    macro avg       0.96      0.95      0.95       160
# weighted avg       0.96      0.95      0.95       160

# %%
plt.plot(info.history['loss'], color='red', label='Train')  
plt.plot(info.history['val_loss'], color='blue', label='Validation') 
plt.title('Loss vs iterarion') 
plt.xlabel('epochs.') 
plt.legend()

# %%
plt.plot(info.history['accuracy'], color='red', label='Train')  
plt.plot(info.history['val_accuracy'], color='blue', label='Validation') 
plt.title('Accuracy vs iterarion') 
plt.xlabel('epochs.') 
plt.legend()

# %%
sns.heatmap(confusion_matrix(y_test_augmented, pred), annot=True, cmap="Blues", square=True,
            xticklabels=np.arange(15), yticklabels=np.arange(15), linewidths=0.5, linecolor='black')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
def predict_celeb(image): 
#     image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.resize(image, (100, 100)) 
#     image = np.array(image) 
    return label_encoder.inverse_transform(cnn_model_v1.predict(image).argmax(axis=1))

# %%
cnn_model_v1.save('./model/final_cnn.h5')
